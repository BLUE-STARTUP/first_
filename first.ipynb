# %%
#2019년과 2020년 영화 관람객 수 비교 분석 및 시각화

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import json
import requests
from bs4 import BeautifulSoup
from pyprnt import prnt
from datetime import datetime, timedelta

# %%
na_2020 = pd.read_csv("./national_2020.csv")
na_2019 = pd.read_csv("./national_2019.csv")
nation = pd.read_csv("./national.csv")
lo_2020 =  pd.read_csv("./local_2020.csv")
lo_2019 =  pd.read_csv("./local_2019.csv")
co_19 = pd.read_csv("./covid_2020.csv",encoding='cp949')

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-52-09f754161c27> in <module>
# ----> 1 lo_2020(column)
#
# NameError: name 'column' is not defined

# %%
# (lo_2020.loc[11] - lo_2019.loc[11]) / lo_2019.loc[11] *100

# %%
# i = 1
# f'{i:0>2}'

# %%
# wide_area_code = 105000

# %%
# wide_area_code

# %%
# res_dict = {}
# for area in range(1,17+1): #
#     #날짜 초기화 -> 20200101 이라는 날짜로 초기화를 해주구요
#     res_list = []
#     for date in range(48):
#         str_date = (datetime(2019,2,5)+timedelta(weeks=date)).strftime('%Y%m%d')
#         payload = { # 아주 잠깐 사용하는 api에게 넘겨줄 dict 타입의 암호!
#         'key':'69f0ff8b462e9199555386e5bd993a0f', #필수
#         'targetDt' : str_date, #필수, 2020년 1월 1일이 포함된 
#         'weekGb' : '0', #선택, 주간의
#         'wideAreaCd' : f'0{wide_area_code+area}' #선택
#         }
#         res = requests.get('http://www.kobis.or.kr/kobisopenapi/webservice/rest/boxoffice/searchWeeklyBoxOfficeList.json', params=payload).json()
#         # res -> 2020년 1월 1일이 포함된 주간의 각 지역별 값인데, 임시 변수
#         df = pd.DataFrame(res['boxOfficeResult']['weeklyBoxOfficeList']) # 껍데기 두 번 벗겨내고 알맹이 가져와서 데이터 프레임으로 변환
#         df['audiCnt'] = df['audiCnt'].apply(pd.to_numeric) # 알고보니 문자였던 친구들을 숫자형으로 캐스팅
#         res_list.append(sum(df['audiCnt'])) # 그 알맹이에서 audiCnt 열에 해당하는 값 을 다 더한 친구를 리절트 리스트에 추가
#         #res_list의 결과는 한 지역의 모든 주차별 관람객 수
#     res_dict[area] = res_list # res[1]->서울 에다가 서울의 모든 주차별 관람객 수를 넣어줄 거예요.

# %%
# local_audience = pd.DataFrame(res_dict)
# local_audience

# %%
# local_audience.to_csv("local_2020.csv")

# %%
# res_dict2 = {}
# res_list2 = []
  
# for date in range(52):
#     str_date = (datetime(2020,1,1)+timedelta(weeks=date)).strftime('%Y%m%d')
#     payload = { # 아주 잠깐 사용하는 api에게 넘겨줄 dict 타입의 암호!
#       'key':'69f0ff8b462e9199555386e5bd993a0f', #필수
#       'targetDt' : str_date, #필수, 2020년 1월 1일이 포함된 
#       'weekGb' : '0', #선택, 주간의
#       }
#     res = requests.get('http://www.kobis.or.kr/kobisopenapi/webservice/rest/boxoffice/searchWeeklyBoxOfficeList.json', params=payload).json()
#     # res -> 2020년 1월 1일이 포함된 주간의 각 지역별 값인데, 임시 변수
#     df = pd.DataFrame(res['boxOfficeResult']['weeklyBoxOfficeList']) # 껍데기 두 번 벗겨내고 알맹이 가져와서 데이터 프레임으로 변환
#     df['audiCnt'] = df['audiCnt'].apply(pd.to_numeric) # 알고보니 문자였던 친구들을 숫자형으로 캐스팅
#     res_list2.append(sum(df['audiCnt'])) # 그 알맹이에서 audiCnt 열에 해당하는 값 을 다 더한 친구를 리절트 리스트에 추가
#     #res_list의 결과는 한 지역의 모든 주차별 관람객 수
#     res_dict2[area] = res_list2 # res[1]->서울 에다가 서울의 모든 주차별 관람객 수를 넣어줄 거예요.

# %%
# area_count2020 = pd.DataFrame(res_dict)
# area_count2020

# %%
# =pd.read_csv("./areaa.csv")

# %%
nation['diff'] = 100 * (nation['2019'] - nation['2020']) / nation['2019']

# %%
nation['abs_diff'] = np.absolute(nation['diff'])

# %%
nation['abs_diff'].head()
# Out:
# 0    80.784519
# 1    37.507183
# 2    56.138369
# 3    80.883242
# 4    87.632818
# Name: abs_diff, dtype: float64

# %%
nation
# Out:
#        2019     2020       diff   abs_diff
# 0   8576335  1647984  80.784519  80.784519
# 1   3856344  2409938  37.507183  37.507183
# 2   3590783  1574976  56.138369  56.138369
# 3   3653517   698434  80.883242  80.883242
# 4   3899805   482296  87.632818  87.632818
# 5   2387872   353744  85.185806  85.185806
# 6   2673944   251533  90.593184  90.593184
# 7   2924414   216152  92.608707  92.608707
# 8   2120525   160458  92.433100  92.433100
# 9   1458474   113713  92.203289  92.203289
# 10   978674   142866  85.402085  85.402085
# 11  6845424   113664  98.339562  98.339562
# 12  5798420   328906  94.327662  94.327662
# 13  3620555   309435  91.453382  91.453382
# 14  3345962   201874  93.966638  93.966638
# 15  3149898   210417  93.319879  93.319879
# 16  5819873   255335  95.612705  95.612705
# 17  6531443   494723  92.425518  92.425518
# 18  3683212   688678  81.302244  81.302244
# 19  4399352   692013  84.270115  84.270115
# 20  4614954  1463804  68.281287  68.281287
# ...

# %%
co_19.head()
# Out:
#       기준 일자  누적 확진자 수  확진자 수
# 0  20200205        19     19
# 1  20200206        23      4
# 2  20200207        24      1
# 3  20200208        24      0
# 4  20200209        27      3

# %%
del co_19['누적 확진자 수']
co_19.head()
# Out:
#       기준 일자  확진자 수
# 0  20200205     19
# 1  20200206      4
# 2  20200207      1
# 3  20200208      0
# 4  20200209      3

# %%
co_19['날짜'] = co_19['기준 일자'].apply(lambda x :pd.to_datetime(str(x),format = '%Y%m%d'))

# %%
co_19.set_index(co_19['날짜'], inplace=True)

# %%
del co_19['기준 일자']
co_19.head()
# Out:
#             확진자 수         날짜
# 날짜
# 2020-02-05     19 2020-02-05
# 2020-02-06      4 2020-02-06
# 2020-02-07      1 2020-02-07
# 2020-02-08      0 2020-02-08
# 2020-02-09      3 2020-02-09

# %%
co_19_weekly = co_19.resample('W-Mon').sum()

# %%
# co_19_weekly = co_19.resample('W-Mon', how = {'날짜' :np.sum}).fillna(0)

# %%
co_19_weekly.head()
# Out:
#             확진자 수
# 날짜
# 2020-02-10     27
# 2020-02-17      3
# 2020-02-24    803
# 2020-03-02   3379
# 2020-03-09   3170

# %%
co_19_weekly
# Out:
#             확진자 수
# 날짜
# 2020-02-10     27
# 2020-02-17      3
# 2020-02-24    803
# 2020-03-02   3379
# 2020-03-09   3170
# 2020-03-16    854
# 2020-03-23    725
# 2020-03-30    700
# 2020-04-06    623
# 2020-04-13    253
# 2020-04-20    137
# 2020-04-27     64
# 2020-05-04     63
# 2020-05-11    108
# 2020-05-18    156
# 2020-05-25    141
# 2020-06-01    297
# 2020-06-08    310
# 2020-06-15    308
# 2020-06-22    317
# 2020-06-29    319
# 2020-07-06    380
# 2020-07-13    342
# 2020-07-20    292
# 2020-07-27    404
# 2020-08-03    214
# 2020-08-10    237
# 2020-08-17    889
# 2020-08-24   2149
# 2020-08-31   2282
# 2020-09-07   1349
# 2020-09-14    989
# 2020-09-21    760
# 2020-09-28    616
# 2020-10-05    503
# 2020-10-12    540
# 2020-10-19    572
# 2020-10-26    680
# 2020-11-02    777
# 2020-11-09    820
# 2020-11-16   1214
# 2020-11-23   2175
# 2020-11-30   3258
# 2020-12-07   3953
# 2020-12-14   5324
# 2020-12-21   7101
# 2020-12-28   7088
# 2021-01-04   3061

# %%
co_19_weekly.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 48 entries, 2020-02-10 to 2021-01-04
# Freq: W-MON
# Data columns (total 1 columns):
# 확진자 수    48 non-null int64
# dtypes: int64(1)
# memory usage: 768.0 bytes

# %%
# co_19_weekly.plot(kind='bar', legend=False, figsize=(15, 10),stacked=False) # 'bar' graph

# plt.show()

# %%
#한글 데이터 시각화 코드
# %matplotlib inline 

from matplotlib import font_manager, rc

plt.style.use('default')

font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)

# %%
# 1. 기본 스타일 설정
plt.rcParams['figure.figsize'] = (15, 10)
plt.rcParams['font.size'] = 15

# 2. 데이터 준비
x = np.array(range(48)) 
y1 = co_19_weekly['확진자 수']
y2 = nation['abs_diff']

# 3. 그래프 그리기
fig, ax1 = plt.subplots()

ax1.plot(x, y2, '-s', color='yellow', markersize=7, linewidth=5, alpha=0.7, label='Price')
# ax1.set_ylim()
# ax1.set_xlabel('reduction_ratio (%)')
ax1.set_ylabel('코로나19 확진자 수(명)')
ax1.tick_params(axis='both', direction='in')

ax2 = ax1.twinx()
ax2.bar(x, y1, color='grey', label='확진자 수', alpha=0.7, width=0.7)
# ax2.set_ylim()
ax2.set_ylabel('영화 관람객 감소율(%)')

ax2.set_zorder(ax1.get_zorder() + 10)
ax2.tick_params(axis='y', direction='in')

# for i, v in enumerate(x):
#     ax2.text(v, y1[i], y1[i],                 # 좌표 (x축 = v, y축 = y[0]..y[1], 표시 = y[0]..y[1])
#              fontsize = 15, 
#              color='blue',
#              horizontalalignment='center',  # horizontalalignment (left, center, right)
#              verticalalignment='top')

# ax1.set_zorder(ax2.get_zorder() + 10)
# ax1.patch.set_visible(False)

plt.grid()
plt.legend()
plt.title('코로나 확진자 수와 영화 관람객 감소율',fontsize=20) ## 타이틀 설정

plt.show()

# %%
# # 1. 기본 스타일 설정
# plt.style.use('default')
# plt.rcParams['figure.figsize'] = (15, 10) # 캔버스 크기 지정
# plt.rcParams['font.size'] = 15            # 폰트 크기 지정
# plt.rc('font', family='NanumBarunGothic') # 한글 깨짐 방지

# # 2. 데이터 준비
# x = np.array(range(48))           # 0~47주
# y1 = covid19_weekly['확진자 수']  # 코로나19 주간 확진자 수
# y2 = national['abs_diff']         # 영화 관람객 감소율

# # 3. 그래프 그리기
# fig, ax1 = plt.subplots()
# ax1.bar(x, y1, label='reductionRatio', color='grey', alpha=0.7, width=0.7)
# ax1.set_ylabel('코로나19 확진자 수(명)')
# ax1.tick_params(axis='both', direction='in')

# ax2 = ax1.twinx()
# ax2.plot(x, y2, '-s', label='decideCnt', color='yellow', marker='o', markersize=7, linewidth=5)
# ax2.set_ylabel('영화 관람객 감소율(%)')
# ax2.tick_params(axis='y', direction='in')

# ax1.set_zorder(ax2.get_zorder() + 10)
# ax1.patch.set_visible(False)

# plt.title('코로나19 확진자 및 영화 관람객 감소율',fontsize=20) ## 타이틀 설정

# plt.show()

# %%
#-----코랩작성코드

# %%
# import matplotlib.pyplot as plt
# import numpy as np

# # 1. 기본 스타일 설정
# plt.style.use('default')
# plt.rcParams['figure.figsize'] = (4, 3)
# plt.rcParams['font.size'] = 12

# # 2. 데이터 준비
# x = np.arange(2020, 2027)
# y1 = np.array([1, 3, 7, 5, 9, 7, 14])
# y2 = np.array([1, 3, 5, 7, 9, 11, 13])

# # 3. 그래프 그리기
# fig, ax1 = plt.subplots()

# ax1.plot(x, y1, '-s', color='green', markersize=7, linewidth=5, alpha=0.7, label='Price')
# ax1.set_ylim(0, 18)
# ax1.set_xlabel('Year')
# ax1.set_ylabel('Price ($)')
# ax1.tick_params(axis='both', direction='in')

# ax2 = ax1.twinx()
# ax2.bar(x, y2, color='deeppink', label='Demand', alpha=0.7, width=0.7)
# ax2.set_ylim(0, 18)
# ax2.set_ylabel(r'Demand ($\times10^6$)')
# ax2.tick_params(axis='y', direction='in')

# plt.show()

# %%
a_nation = na_2019['전국']
b_nation = na_2020['전국']
# c_covid = co_2020['확진자 수']

# %%
print(list(na_2019.index)) <- 기준 일자 열로 대체
# Out:
#   File "<ipython-input-36-b91b1705f65f>", line 1
#     print(list(na_2019.index)) <- 기준 일자 열로 대체
#                                       ^
# SyntaxError: invalid syntax

# %%
#한글 데이터 시각화 코드
# %matplotlib inline 

from matplotlib import font_manager, rc

font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)

# %%
# # colab 나눔 폰트 설치
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# 'sudo'은(는) 내부 또는 외부 명령, 실행할 수 있는 프로그램, 또는
# 배치 파일이 아닙니다.
# 'sudo'은(는) 내부 또는 외부 명령, 실행할 수 있는 프로그램, 또는
# 배치 파일이 아닙니다.
# 'rm'은(는) 내부 또는 외부 명령, 실행할 수 있는 프로그램, 또는
# 배치 파일이 아닙니다.

# %%
x = np.array(range(48)) # 0~47주

# %%
# plt.rc('font', family='NanumBarunGothic') # 한글 깨짐 방지
plt.figure(figsize=(15,8)) ## 캔버스 생성

plt.plot(x, nation['2019'], marker='o',label='2019') ## 선그래프 생성
plt.plot(x, nation['2020'], marker='o',label='2020')  

plt.grid()
plt.legend() ## 범례
plt.title('영화 관람객 수(단위 : 100만 명)',fontsize=20) ## 타이틀 설정()

plt.show()

# %%
lo_2019
# Out:
#         서울시      경기도     강원도    충청북도    충청남도    경상북도    경상남도    전라북도    전라남도  \
# 0   1927755  2183453  230244  244894  287279  309956  477811  284389  227935
# 1    933062   967626  101516  105983  132458  126681  197656  116227   93135
# 2    917498   877939   90879   95675  109331  115097  182715  104725   83199
# 3    907147   894088   93399  100433  119648  120272  191655  110647   84607
# 4   1045831   972144   95670  101277  128707  114126  187644  113831   76957
# 5    673098   585862   59076   60634   77451   69233  110880   65695   46565
# 6    715881   643216   66058   70991   89560   83377  127737   78974   57178
# 7    806827   718643   72222   75621   95805   85517  128452   83520   54501
# 8    575492   502559   52438   54253   70724   61697  105203   60204   44517
# 9    384838   329446   35910   39879   46909   45615   77516   42952   35420
# 10   258646   227080   24866   26958   33211   30380   51759   29314   25996
# ...

# %%
lo_2019.columns
# Out:
# Index(['서울특별시', '경기도', '강원도', '충청북도', '충청남도', '경상북도', '경상남도', '전라북도', '전라남도',
#        '제주특별자치도', '부산광역시', '대구광역시', '대전광역시', '울산광역시', '인천광역시', '광주광역시',
#        '세종특별자치시'],
#       dtype='object')

# %%
lo_2019.rename(columns = {'서울시' : '서울특별시','제주도' : '제주특별자치도', '세종시':'세종특별자치시',
                         '부산시' : '부산광역시', '대구시' : '대구광역시', '울산시' : '울산광역시',
                         '대전시' : '대전광역시', '인천시' : '인천광역시', '광주시' : '광주광역시'},
               inplace = True)

# %%
local_diff= (lo_2019.loc[11] - lo_2020.loc[11])/lo_2019.loc[11] *100

# %%
lolo = pd.DataFrame(local_diff)

# %%
lolo
# Out:
#                감소율
# 강원도      98.383487
# 경기도      98.382271
# 경상남도     98.599426
# 경상북도     99.212517
# 광주광역시          NaN
# 광주시            NaN
# 대구광역시          NaN
# 대구시            NaN
# 대전광역시          NaN
# 대전시            NaN
# 부산광역시          NaN
# 부산시            NaN
# 서울시            NaN
# 서울특별시          NaN
# 세종시            NaN
# 세종특별자치시        NaN
# 울산광역시          NaN
# 울산시            NaN
# 인천광역시          NaN
# 인천시            NaN
# 전라남도     98.399300
# 전라북도     98.774183
# 제주도            NaN
# 제주특별자치도        NaN
# 충청남도     98.434968
# 충청북도     98.821555

# %%
lolo.columns=['감소율']

# %%
import folium
import json

geo_path = 'skorea-2018-provinces-geo.json'
geo_str = json.load(open(geo_path, encoding='utf-8'))

# %%
df_temp = lolo.columns

# %%
df_temp.columns = ['감소율']

# %%
df_temp.index = [~~~~]
# Out:
#   File "<ipython-input-132-7634702ad939>", line 1
#     df_temp.index = [~~~~]
#                          ^
# SyntaxError: invalid syntax

# %%
for province in geo_str['features']:
    print(province['properties']['name'])
# Out:
# 서울특별시
# 부산광역시
# 대구광역시
# 인천광역시
# 광주광역시
# 대전광역시
# 울산광역시
# 세종특별자치시
# 경기도
# 강원도
# 충청북도
# 충청남도
# 전라북도
# 전라남도
# 경상북도
# 경상남도
# 제주특별자치도

# %%
map = folium.Map(location=[37.5502, 126.982], zoom_start=7, tiles='Stamen Toner')

map.choropleth(geo_data = geo_str,               
               data = df_temp['감소율'], 
               columns = [df_temp.index, df_temp['감소율']],
               fill_color = 'PuRd',
               
               key_on = 'feature.properties.name')
               # geo_str['features'][0] -> {..., 'properties': {'name': '종로구', ...}} <- properties.name 에 대응됩니다.
map
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-134-73c6a021562f> in <module>
#       2
#       3 map.choropleth(geo_data = geo_str,
# ----> 4                data = df_temp['감소율'],
#       5                columns = [df_temp.index, df_temp['감소율']],
#       6                fill_color = 'PuRd',
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in __getitem__(self, key)
#    3956         if is_scalar(key):
#    3957             key = com.cast_scalar_indexer(key)
# -> 3958             return getitem(key)
#    3959
#    3960         if isinstance(key, slice):
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices
