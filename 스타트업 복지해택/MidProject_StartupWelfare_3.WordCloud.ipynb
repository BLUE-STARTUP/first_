# %%
import pandas as pd

df = pd.read_json('투자 유치 100억이상 회사 복지 혜택.json')

# %%
#결측치를 공백으로 채우기
df = df.fillna('')
df.head()
# Out:
#             index                                             근무 형태  \
# 0             위메프          https://recruit.wemakeprice.com/#Benefit
# 1              클룩                                     AM 10 - PM 07
# 10   (주)제이엘케이인스펙션                                     AM 09 - PM 06
# 100         코인플러그                      AM 09 - PM 06, AM 10 - PM 07
# 101           스포카  도도데이(월1회 조기퇴근), 월~금(주 5일제), 유연 근무, AM 10 - PM 07
#
#                                                 식사, 간식  \
# 0
# 1                                   간식 무한 제공, 고급 커피 제공
# 10   아침 녹즙 구매 비용 지원, 식비 전액 지원, 고급 커피 제공, 석식 제공, 중식 ...
# 100               주1회 점심 제공, 고급 커피 제공, 간식 무한 제공, 석식 제공
# 101                                     야근 식비지원, 간식 제공
#
#                                                 연차, 휴가  \
# 0
# 1                                           자율 휴가제, 월차
# 10                                생리 휴가, 출산 휴가, 자율 휴가제
# 100                                    근로기준법에 의한 휴가 제공
# ...

# %%
df = df.drop(index=0, axis=0)
df = df.reset_index(drop=True)
df.head()
# Out:
#           index                                             근무 형태  \
# 0            클룩                                     AM 10 - PM 07
# 1  (주)제이엘케이인스펙션                                     AM 09 - PM 06
# 2         코인플러그                      AM 09 - PM 06, AM 10 - PM 07
# 3           스포카  도도데이(월1회 조기퇴근), 월~금(주 5일제), 유연 근무, AM 10 - PM 07
# 4          포도트리                              유연 근무, AM 10 - PM 07
#
#                                               식사, 간식  \
# 0                                 간식 무한 제공, 고급 커피 제공
# 1  아침 녹즙 구매 비용 지원, 식비 전액 지원, 고급 커피 제공, 석식 제공, 중식 ...
# 2               주1회 점심 제공, 고급 커피 제공, 간식 무한 제공, 석식 제공
# 3                                     야근 식비지원, 간식 제공
# 4                             간식 무한 제공, 석식 제공, 중식 제공
#
#                                               연차, 휴가  \
# 0                                         자율 휴가제, 월차
# 1                               생리 휴가, 출산 휴가, 자율 휴가제
# 2                                    근로기준법에 의한 휴가 제공
# ...

# %%
#컬럼명 변경
df.columns = ['Company_name','Work type','meals_snacks','annual leave, vacation','insurance, medical service','equipment','self development','transportaion']
df.head()
# Out:
#    Company_name                                         Work type  \
# 0            클룩                                     AM 10 - PM 07
# 1  (주)제이엘케이인스펙션                                     AM 09 - PM 06
# 2         코인플러그                      AM 09 - PM 06, AM 10 - PM 07
# 3           스포카  도도데이(월1회 조기퇴근), 월~금(주 5일제), 유연 근무, AM 10 - PM 07
# 4          포도트리                              유연 근무, AM 10 - PM 07
#
#                                        meals, snacks  \
# 0                                 간식 무한 제공, 고급 커피 제공
# 1  아침 녹즙 구매 비용 지원, 식비 전액 지원, 고급 커피 제공, 석식 제공, 중식 ...
# 2               주1회 점심 제공, 고급 커피 제공, 간식 무한 제공, 석식 제공
# 3                                     야근 식비지원, 간식 제공
# 4                             간식 무한 제공, 석식 제공, 중식 제공
#
#                               annual leave, vacation  \
# 0                                         자율 휴가제, 월차
# 1                               생리 휴가, 출산 휴가, 자율 휴가제
# 2                                    근로기준법에 의한 휴가 제공
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-270a6d1a0e61> in <module>
# ----> 1 print(tfidfv.vocabulary_)
#
# NameError: name 'tfidfv' is not defined
